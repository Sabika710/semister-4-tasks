# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier

# %%
test = pd.read_csv("test.csv")
train = pd.read_csv("train.csv")
train
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
train.drop(["Name","Cabin","PassengerId","RoomService","FoodCourt","ShoppingMall"], axis=1 , inplace = True)
test.drop(["Name","Cabin","PassengerId","RoomService","FoodCourt","ShoppingMall"], axis=1 , inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HomePlanet   8492 non-null   object
#  1   CryoSleep    8476 non-null   object
#  2   Destination  8511 non-null   object
#  3   Age          8514 non-null   float64
#  4   VIP          8490 non-null   object
#  5   Spa          8510 non-null   float64
#  6   VRDeck       8505 non-null   float64
#  7   Transported  8693 non-null   bool
# dtypes: bool(1), float64(3), object(4)
# memory usage: 484.0+ KB

# %%
def fillobj(cols):
  for i in cols:
    train[i] = train[i].fillna(train[i].mode()[0])
col=["HomePlanet","CryoSleep","Destination","VIP"]
fillobj(col)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12420\1619070867.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train[i] = train[i].fillna(train[i].mode()[0])

# %%
def fillfloat(cols):
    for i in cols:
        train[i]=train[i].fillna(train[i].mean())
cols=["Age","Spa","VRDeck"]
fillfloat(cols)

# %%
train.isnull().sum()
# Out:
# HomePlanet     0
# CryoSleep      0
# Destination    0
# Age            0
# VIP            0
# Spa            0
# VRDeck         0
# Transported    0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HomePlanet   8693 non-null   object
#  1   CryoSleep    8693 non-null   bool
#  2   Destination  8693 non-null   object
#  3   Age          8693 non-null   float64
#  4   VIP          8693 non-null   bool
#  5   Spa          8693 non-null   float64
#  6   VRDeck       8693 non-null   float64
#  7   Transported  8693 non-null   bool
# dtypes: bool(3), float64(3), object(2)
# memory usage: 365.2+ KB

# %%
def objtoint(col):
    encoder = LabelEncoder()
    for i in col:
        train[i]= encoder.fit_transform(train[i])
col=["HomePlanet","CryoSleep","Destination","VIP","Transported"]
objtoint(col)

# %%
def floattoint(col):
    for i in col:
        train[i]=train[i].astype("int64")
cols=["Age","Spa","VRDeck"]       
floattoint(cols)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HomePlanet   8693 non-null   int32
#  1   CryoSleep    8693 non-null   int64
#  2   Destination  8693 non-null   int32
#  3   Age          8693 non-null   int64
#  4   VIP          8693 non-null   int64
#  5   Spa          8693 non-null   int64
#  6   VRDeck       8693 non-null   int64
#  7   Transported  8693 non-null   int64
# dtypes: int32(2), int64(6)
# memory usage: 475.5 KB

# %%
def fillobj(cols):
  for i in cols:
    test[i] = test[i].fillna(test[i].mode()[0])
col=["HomePlanet","CryoSleep","Destination","VIP"]
fillobj(col)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12420\3567363578.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test[i] = test[i].fillna(test[i].mode()[0])

# %%
def fillfloat(cols):
    for i in cols:
        test[i]=train[i].fillna(test[i].mean())
cols=["Age","Spa","VRDeck"]
fillfloat(cols)

# %%
def objtoint(col):
    encoder = LabelEncoder()
    for i in col:
        test[i]= encoder.fit_transform(test[i])
col=["HomePlanet","CryoSleep","Destination","VIP"]
objtoint(col)

# %%
def floattoint(col):
    for i in col:
        test[i]=test[i].astype("int64")
cols=["Age","Spa","VRDeck"]       
floattoint(cols)

# %%
train_x = train.drop("Transported",axis=1)
train_y = train["Transported"]
test_x = test

# %%
model1 = RandomForestClassifier()
model1.fit(train_x, train_y)
# Out:
# RandomForestClassifier()

# %%
testdata = pd.read_csv('test.csv')

# %%
predicted = model1.predict(test_x)
predicted
pridicted = np.where(predicted == 1, True,False)

# %%
pridicted
# Out:
# array([ True,  True,  True, ...,  True, False, False])

# %%
submission = pd.DataFrame({'PassengerId':testdata['PassengerId'],'Transported':pridicted})
submission.to_csv('submission.csv', index=False)
